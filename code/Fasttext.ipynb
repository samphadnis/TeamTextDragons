# %%
import pandas as pd
import pickle
import numpy as np
import json
import csv
import fasttext
from sklearn.model_selection import train_test_split

# %%
train_raw = pd.read_json("data/train.jsonl", lines=True, encoding="utf-8")
test_raw = pd.read_json("data/test.jsonl", lines=True, encoding="utf-8")

# %%
train_raw['conext_string'] = train_raw.context.apply(lambda x: ' '.join(x[::-1][:3]))
test_raw['conext_string'] = test_raw.context.apply(lambda x: ' '.join(x[::-1][:3]))

# %%
train_raw.head(10)
# Out:
#      label                                           response  \
# 0  SARCASM  @USER @USER @USER I don't get this .. obviousl...
# 1  SARCASM  @USER @USER trying to protest about . Talking ...
# 2  SARCASM  @USER @USER @USER He makes an insane about of ...
# 3  SARCASM  @USER @USER Meanwhile Trump won't even release...
# 4  SARCASM  @USER @USER Pretty Sure the Anti-Lincoln Crowd...
# 5  SARCASM  @USER @USER @USER -> per your tag line : never...
# 6  SARCASM  @USER @USER he does ! It excites him then he k...
# 7  SARCASM  Oh look , it's the #racist @USER offering soli...
# 8  SARCASM  @USER @USER @USER As they are the biggest bull...
# 9  SARCASM  @USER @USER @USER responds to facts by tossing...
#
#                                              context  \
# 0  [A minor child deserves privacy and should be ...
# 1  [@USER @USER Why is he a loser ? He's just a P...
# 2  [Donald J . Trump is guilty as charged . The e...
# 3  [Jamie Raskin tanked Doug Collins . Collins lo...
# 4  [Man ... y ’ all gone “ both sides ” the apoca...
# 5  [Donald Trump tapped into voters ’ populist sh...
# 6  [@USER @USER Coo-Coo . Keep on supporting fema...
# 7  [Hi , I'm Dennis , I'll be looking after lily'...
# 8  [Tips for children and young people from @USER...
# 9  [The response of Sanders ' team to his quote f...
#
#                                        conext_string
# 0  @USER If your child isn't named Barron ... #Be...
# 1  @USER @USER having to make up excuses of why y...
# 2  @USER I ’ ll remember to not support you at th...
# 3  @USER But not half as stupid as Schiff looks ....
# 4  @USER They already did . Obama said many times...
# 5  @USER because these privileged white boys are ...
# 6  @USER @USER do you masturbate to these videos ...
# 7  @USER Dennis please pass on my love and solida...
# 8  @USER @USER @USER Please forward on to the Soc...
# 9  @USER Careful , Bernie ’ s supporters get trig...

# %%
train_raw['Target'] = train_raw['label'].apply(lambda x: '__label__'+x)
train_raw['all_string'] = train_raw['response'] + ". " + train_raw['conext_string']
test_raw['all_string'] = test_raw['response'] + ". " + test_raw['conext_string']

# %%
train_raw['all_string'] = train_raw['all_string'].apply(lambda x: x.lower())
test_raw['all_string'] = test_raw['all_string'].apply(lambda x: x.lower())

# %%
X_train, X_test, y_train, y_test = train_test_split(train_raw[['all_string']], train_raw['Target'], test_size=0.33, random_state=100)

# %%
train_all = X_train
train_all['Target'] = y_train
test_all = X_test
test_all['Target'] = y_test

# %%
train_all
# Out:
#                                              all_string                Target
# 2417  @user @user @user anybody else think marc mart...      __label__SARCASM
# 1516  @user so u r not only ignorant of basic econmc...      __label__SARCASM
# 3342  demning leaders = " diversity is our strength ...  __label__NOT_SARCASM
# 3750  @user @user @user ahh good catch , cant rememb...  __label__NOT_SARCASM
# 579   @user woo hoo i made the cut . lol you know , ...      __label__SARCASM
# ...                                                 ...                   ...
# 4149  @user @user ok great ! the girls and i will se...  __label__NOT_SARCASM
# 1890  @user @user @user don't disagree with dave ......      __label__SARCASM
# 350   @user @user or how about they are substantiate...      __label__SARCASM
# 79    @user delayed as in the had to use @user to ge...      __label__SARCASM
# 3927  @user #loved hearing you on train that was a l...  __label__NOT_SARCASM
#
# [3350 rows x 2 columns]

# %%
train_all[['Target', 'all_string']].to_csv('train.txt', header=None, index=None, sep=' ', quoting=csv.QUOTE_NONE, escapechar = ' ')
test_all[['Target', 'all_string']].to_csv('test.txt', header=None, index=None, sep=' ', quoting=csv.QUOTE_NONE, escapechar = ' ')

# %%
model = fasttext.train_supervised('train.txt', lr=0.0075, dim=50, epoch=100, ws=10, wordNgrams=2, minn=5)

# %%
print(model.words)
# Out:
# ['@user', '.', 'the', ',', 'to', 'a', 'and', 'you', 'i', 'of', 'is', '!', 'in', '</s>', 'it', 'that', 'for', '?', '’', '<url>', '"', 'this', 'are', 'not', 'on', 'be', 'have', 'with', 'your', 'we', 'my', 'but', 'all', '...', 'was', 'they', 'so', '&', '..', 'as', 's', 'me', 'what', 'he', 'will', 'if', 'just', 'like', 'do', 'people', 'who', 'no', 'from', 'at', 'or', 'about', 'can', '-', 'by', 'one', 'an', ':', 'his', 't', 'has', 'how', 'our', 'out', 'when', 'get', "it's", 'up', ')', 'more', 'know', 'trump', '(', 'their', "don't", 'there', "'", 'love', 'us', 'now', 'would', 'them', '/', 'think', "i'm", 'been', 'good', '️', 'time', 'she', 'because', 'him', '“', 'some', 'only', 'want', '<url>.', 'her', 'should', 'day', '”', 'here', 'see', 'why', 'u', 'make', 'right', 'need', 'being', 'had', 'then', 'were', 'even', 'go', 'very', 'too', 'than', 'did', 'much', 'never', 'still', 'many', 'way', 'thank', 'back', 'over', 'say', '2', 'going', 'well', 'those', 'any', 'got', 'am', 'really', 'other', 'also', '…', 'said', 'which', "you're", 'm', 'new', 'world', 'after', '😂', 'always', 'great', 'life', 'these', 'years', 'take', 'thanks', 'yes', "that's", 'could', 'better', 'please', 'same', 'don', 'most', 'may', '*', 'god', 'work', 'someone', 'into', '1', 'every', 'let', 'sure', "can't", 're', 'today', 'where', 'first', 'does', 'oh', 'help', 'nothing', 'last', 'things', 'its', 'look', 'president', 'made', 'again', 'year', 'hope', 'give', 'thing', 'best', 'read', 'come', "didn't", 'down', 'tweet', '!.', 'everyone', 'lol', 'off', 'country', 'before', '$', 'keep', 'w', 'use', 'own', 'believe', 'actually', 'doing', ';', 'happy', 'must', 'true', "doesn't", 'another', 'against', 'something', 'bad', '❤', '?.', 'twitter', 'support', 'live', 'feel', 'hate', 'man', 'call', 'such', '3', 'yet', 'tell', 'real', 'ever', 'while', '—', 'point', "i've", 'show', 'white', 'says', 'wrong', 'stop', 'anyone', 've', 'through', 'name', 'put', '%', 'away', 'vote', 'part', 'left', 'find', 'little', 'news', 'already', 'around', 'free', 'person', 'since', '🤣', 'lot', 'trying', 'without', 'big', 'yeah', 'hard', 'heart', 'done', '4', 'try', 'family', 'next', 'change', 'anything', 'two', 'care', 'maybe', 'women', 'money', 'everything', 'fact', 'others', 'saying', 'mean', 'words', 'told', 'sorry', 'thought', 'both', 'media', 'america', '🙏', '\u200d', 'kind', 'team', 'understand', 'enough', 'house', 'war', "he's", "isn't", 'having', 'ok', 'called', 'needs', 'guy', 'lost', 'getting', 'working', 'makes', 'making', 'job', 'iran', 'obama', 'might', 'friends', 'remember', 'long', "i'll", 'funny', 'won', 'party', 'wants', '+', 'r', 'watch', 'morning', 'wish', 'amazing', 'agree', 'hear', 'place', 'racist', 'old', 'guys', 'ur', 'game', 'd', 'calling', 'win', 'n', '>', 'end', 'used', 'voted', 'guess', 'yourself', 'beautiful', 'though', 'american', 'else', 'wait', 'problem', 'woman', 'talking', 'stay', 'pay', 'word', 'dear', 'until', 'state', '2020', "won't", 'top', 'days', 'reason', 'share', 'mind', 'week', 'looking', 'talk', 'history', 'home', 'different', 'sense', 'took', 'night', 'phone', 'story', 'times', 'full', 'kids', 'coming', 'hey', 'political', 'exactly', 'question', '10', 'idea', 'means', 'play', 'run', 'ppl', 'each', 'probably', 'seen', 'few', 'thinking', 'black', 'truth', 'wow', '5', 'start', 'children', 'election', 'post', 'case', 'ago', 'school', 'far', "they're", 'soon', '=', '@user.', 'etc', 'hi', 'act', "there's", 'law', 'seems', '....', 'went', 'doesn', 'taking', 'matter', 'whole', 'came', 'government', 'enjoy', 'service', 'less', 'friend', '👍', 'instead', 'able', 'myself', 'human', 'learn', 'bernie', 'together', 'important', 'least', 'hillary', 'uk', 'once', 'sad', 'under', 'either', "we're", "what's", 'follow', 'fun', 'nice', 'ask', 'past', 'course', 'video', '😊', "i'd", 'found', 'stand', 'looks', 'forward', 'll', 'speech', 'campaign', 'using', 'move', 'men', 'b', 'lives', 'deal', 'small', 'million', 'clear', 'truly', 'respect', 'speak', 'fake', 'public', 'book', 'o ...

# %%
len(model.words)
# Out:
# 24852

# %%
def print_results(N, p, r):
    print("N\t" + str(N))
    print("P@{}\t{:.10f}".format(1, p))
    print("R@{}\t{:.10f}".format(1, r))

print_results(*model.test('test.txt'))
# Out:
# N	1650
# P@1	0.6515151515
# R@1	0.6515151515

# %%
test_pred=test_all

def predict_label(row):
    return model.predict(row['all_string'])
test_pred['predictions'] = test_pred.apply(predict_label,axis=1)
test_pred['Pred_label'] = test_pred['predictions'].apply(lambda x:x[0][0])
test_pred['Pred_prob'] = test_pred['predictions'].apply(lambda x: x[1][0] if (x[0][0] == '__label__SARCASM') else 1-x[1][0])
test_pred['True_prob'] = test_pred['Target'].apply(lambda x: 1 if x == '__label__SARCASM' else 0)

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(test_pred['Target'], test_pred['Pred_label'])
# Out:
# (array([0.6844584 , 0.63079961]),
#  array([0.5382716 , 0.76071429]),
#  array([0.60262612, 0.68969239]),
#  array([810, 840], dtype=int64))

# %%
test_pred=test_raw

def predict_label(row):
    return model.predict(row['response'])
test_pred['predictions'] = test_pred.apply(predict_label,axis=1)
test_pred['Pred_label'] = test_pred['predictions'].apply(lambda x:x[0][0])
test_pred['Pred_prob'] = test_pred['predictions'].apply(lambda x:x[1][0])
test_pred['Pred_label2'] = test_pred['Pred_label'].apply(lambda x:x.replace("__label__", ""))

# %%
test_pred
# Out:
#                 id                                           response  \
# 0        twitter_1  @USER @USER @USER My 3 year old , that just fi...
# 1        twitter_2  @USER @USER How many verifiable lies has he to...
# 2        twitter_3  @USER @USER @USER Maybe Docs just a scrub of a...
# 3        twitter_4  @USER @USER is just a cover up for the real ha...
# 4        twitter_5  @USER @USER @USER The irony being that he even...
# ...            ...                                                ...
# 1795  twitter_1796  @USER @USER @USER is definitely the best out t...
# 1796  twitter_1797  @USER @USER Ye let her out run wild and infect...
# 1797  twitter_1798  @USER @USER @USER Thanks for that , I would ha...
# 1798  twitter_1799  @USER @USER @USER Yes also #found this on #new...
# 1799  twitter_1800  @USER @USER @USER you still need to send the l...
#
#                                                 context  \
# 0     [Well now that ’ s problematic AF <URL>, @USER...
# 1     [Last week the Fake News said that a section o...
# 2     [@USER Let ’ s Aplaud Brett When he deserves i...
# 3     [Women generally hate this president . What's ...
# 4     [Dear media Remoaners , you excitedly sharing ...
# ...                                                 ...
# 1795  [I have been a business customer of MWeb @USER...
# 1796  [A woman refuses to have her temperature taken...
# 1797  [The reason big government wants @USER out is ...
# 1798  [Happy #musicmonday and #thanks for #all your ...
# 1799  [Not long wrapped on the amazing #January22nd ...
#
#                                           conext_string  \
# 0     @USER @USER @USER No .. he actually in the gif...
# 1     @USER The mainstream media doesn't report the ...
# 2     @USER @USER He did try keep korkmaz in in the ...
# 3     @USER I've hated him before he was placed in o...
# 4     @USER @USER Quite an articulate and considered...
# ...                                                 ...
# 1795  @USER @USER It ’ s time for @USER , 24/7 frien...
# 1796  @USER Disgusting i hope this world burns A wom...
# 1797  @USER @USER @USER Tell Obama that . Throughout...
# 1798  @USER @USER @USER I totally agree ! Music is s...
# 1799  @USER @USER Hey Roy , thanks very much for bei...
#
#                                              all_string  \
# 0     @user @user @user my 3 year old , that just fi...
# 1     @user @user how many verifiable lies has he to...
# 2     @user @user @user maybe docs just a scrub of a...
# 3     @user @user is just a cover up for the real ha...
# 4     @user @user @user the irony being that he even...
# ...                                                 ...
# 1795  @user @user @user is definitely the best out t...
# 1796  @user @user ye let her out run wild and infect...
# 1797  @user @user @user thanks for that , i would ha...
# 1798  @user @user @user yes also #found this on #new...
# 1799  @user @user @user you still need to send the l...
#
#                                           predictions            Pred_label  \
# 0         ((__label__SARCASM,), [0.5334812998771667])      __label__SARCASM
# 1          ((__label__SARCASM,), [0.544791042804718])      __label__SARCASM
# 2          ((__label__SARCASM,), [0.500037670135498])      __label__SARCASM
# 3     ((__label__NOT_SARCASM,), [0.5302925109863281])  __label__NOT_SARCASM
# 4         ((__label__SARCASM,), [0.5540772676467896])      __label__SARCASM
# ...                                               ...                   ...
# 1795  ((__label__NOT_SARCASM,), [0.5591954588890076])  __label__NOT_SARCASM
# 1796  ((__label__NOT_SARCASM,), [0.5153915882110596])  __label__NOT_SARCASM
# 1797      ((__label__SARCASM,), [0.5189510583877563])      __label__SARCASM
# 1798  ((__label__NOT_SARCASM,), [0.5063786506652832])  __label__NOT_SARCASM
# 1799  ((__label__NOT_SARCASM,), [0.6154927611351013])  __label__NOT_SARCASM
#
#       Pred_prob  Pred_label2
# 0      0.533481      SARCASM
# 1      0.544791      SARCASM
# 2      0.500038      SARCASM
# 3      0.530293  NOT_SARCASM
# 4      0.554077      SARCASM
# ...         ...          ...
# 1795   0.559195  NOT_SARCASM
# 1796   0.515392  NOT_SARCASM
# 1797   0.518951      SARCASM
# 1798   0.506379  NOT_SARCASM
# 1799   0.615493  NOT_SARCASM
#
# [1800 rows x 9 columns]

# %%
test_pred[['id', 'Pred_label2']].to_csv('answer.txt', header=None, index=None, sep=',', quoting=csv.QUOTE_NONE, escapechar = ' ')
